# %%
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
import glob
for f in glob.glob("WFC3*.sens.*fits"):
    tab = Table.read(f)
    plt.plot(tab["WAVELENGTH"],tab["SENSITIVITY"],label=f)

# %%
tab = Table.read("/Users/npirzkal/Dropbox/aXeSIM_WFC3/CONF/WFC3.IR.G141.1st.sens.1.fits")
plt.plot(tab["WAVELENGTH"],tab["SENSITIVITY"],label=f)
tab = Table.read("WFC3.IR.G141.1st.sens.2.fits")
plt.plot(tab["WAVELENGTH"],tab["SENSITIVITY"],label=f)

# %%
tab = Table.read("WFC3.IR.G102.1st.sens.2.fits")
plt.plot(tab["WAVELENGTH"],tab["SENSITIVITY"])
